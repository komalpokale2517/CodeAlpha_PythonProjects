# %%
Oustocks = {
    "AAPL": 180,
    "TSLA": 250,
    "GOOGLE": 200,
    "AMZN": 150
}

total_investment = 0

print("📈 Welcome to Stock Portfolio Tracker\n")

for stock_name in stocks:

    print(f"Stock: {stock_name}")
    print(f"Price per share: {stocks[stock_name]}")

    quantity = int(input("Enter quantity: "))

    investment = stocks[stock_name] * quantity

    print(f"Investment in {stock_name}: {investment}\n")

    total_investment += investment

print("-----------------------")
print("💰 Total Investment Value =", total_investment)
print("------------------------")
# Out:
# 📈 Welcome to Stock Portfolio Tracker
#
# Stock: AAPL
# Price per share: 180
# Enter quantity:  1
# Investment in AAPL: 180
#
# Stock: TSLA
# Price per share: 250
# Enter quantity:  2
# Investment in TSLA: 500
#
# Stock: GOOGLE
# Price per share: 200
# Enter quantity:  3
# Investment in GOOGLE: 600
#
# Stock: AMZN
# Price per share: 150
# Enter quantity:  4
# Investment in AMZN: 600
#
# -----------------------
# 💰 Total Investment Value = 1880
# ------------------------
